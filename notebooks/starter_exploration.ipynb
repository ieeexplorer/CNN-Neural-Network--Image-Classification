# %% [markdown]
# # CIFAR-10 starter exploration\n\nThis notebook is only a lightweight starter file so the repository feels complete on GitHub.\nYou can expand it later with EDA, sample visualisation, confusion matrix analysis, or experiment notes.

# %%
import tensorflow as tf\nfrom matplotlib import pyplot as plt\n\n(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()\nclass_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']\n\nplt.figure(figsize=(8, 8))\nfor i in range(9):\n    plt.subplot(3, 3, i + 1)\n    plt.imshow(x_train[i])\n    plt.title(class_names[int(y_train[i])])\n    plt.axis('off')\nplt.tight_layout()\nplt.show()
